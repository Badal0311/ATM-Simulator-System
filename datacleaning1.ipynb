# %% [markdown]
# <a href="https://colab.research.google.com/github/Badal0311/ATM-Simulator-System/blob/master/datacleaning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/amazon_fires.csv',encoding='ISO-8859-1')
df1
# Out:
#        ano       mes     estado   numero  encontro
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df1.columns
d = {'ano':'year', 'mes':'month', 'estado':'state', 'numero':'no_of_fires', 'encontro':'date'}
df1.rename(columns=d,inplace=True)
df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   Janeiro       Acre     0 Fires  1/1/1998
# 1     1999   Janeiro       Acre     0 Fires  1/1/1999
# 2     2000   Janeiro       Acre     0 Fires  1/1/2000
# 3     2001   Janeiro       Acre     0 Fires  1/1/2001
# 4     2002   Janeiro       Acre     0 Fires  1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  Dezembro  Tocantins         128  1/1/2012
# 6450  2013  Dezembro  Tocantins          85  1/1/2013
# 6451  2014  Dezembro  Tocantins         223  1/1/2014
# 6452  2015  Dezembro  Tocantins         373  1/1/2015
# 6453  2016  Dezembro  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
d = {'ano':'year', 'mes':'month', 'estado':'state', 'numero':'no_of_fires', 'encontro':'date'}
df1.rename(columns=d,inplace=True)
df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   Janeiro       Acre     0 Fires  1/1/1998
# 1     1999   Janeiro       Acre     0 Fires  1/1/1999
# 2     2000   Janeiro       Acre     0 Fires  1/1/2000
# 3     2001   Janeiro       Acre     0 Fires  1/1/2001
# 4     2002   Janeiro       Acre     0 Fires  1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  Dezembro  Tocantins         128  1/1/2012
# 6450  2013  Dezembro  Tocantins          85  1/1/2013
# 6451  2014  Dezembro  Tocantins         223  1/1/2014
# 6452  2015  Dezembro  Tocantins         373  1/1/2015
# 6453  2016  Dezembro  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df1['no_of_fires'] = df1['no_of_fires'].str.strip('Fires')
df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   Janeiro       Acre          0   1/1/1998
# 1     1999   Janeiro       Acre          0   1/1/1999
# 2     2000   Janeiro       Acre          0   1/1/2000
# 3     2001   Janeiro       Acre          0   1/1/2001
# 4     2002   Janeiro       Acre          0   1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  Dezembro  Tocantins         128  1/1/2012
# 6450  2013  Dezembro  Tocantins          85  1/1/2013
# 6451  2014  Dezembro  Tocantins         223  1/1/2014
# 6452  2015  Dezembro  Tocantins         373  1/1/2015
# 6453  2016  Dezembro  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df1.drop_duplicates(inplace=True)
df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   Janeiro       Acre          0   1/1/1998
# 1     1999   Janeiro       Acre          0   1/1/1999
# 2     2000   Janeiro       Acre          0   1/1/2000
# 3     2001   Janeiro       Acre          0   1/1/2001
# 4     2002   Janeiro       Acre          0   1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  Dezembro  Tocantins         128  1/1/2012
# 6450  2013  Dezembro  Tocantins          85  1/1/2013
# 6451  2014  Dezembro  Tocantins         223  1/1/2014
# 6452  2015  Dezembro  Tocantins         373  1/1/2015
# 6453  2016  Dezembro  Tocantins         119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
d = {'Janeiro':'January', 'Fevereiro':'Febraury', 'Março':'March', 'Abril':'April', 'Maio':'May', 'Junho':'June', 'Julho':'July',
       'Agosto':'August', 'Setembro':'September', 'Outubro':'October', 'Novembro':'November', 'Dezembro':'December'}
df1['month'] = df1['month'].map(d)
df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   January       Acre          0   1/1/1998
# 1     1999   January       Acre          0   1/1/1999
# 2     2000   January       Acre          0   1/1/2000
# 3     2001   January       Acre          0   1/1/2001
# 4     2002   January       Acre          0   1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  December  Tocantins         128  1/1/2012
# 6450  2013  December  Tocantins          85  1/1/2013
# 6451  2014  December  Tocantins         223  1/1/2014
# 6452  2015  December  Tocantins         373  1/1/2015
# 6453  2016  December  Tocantins         119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df1['no_of_fires'] = df1['no_of_fires'].fillna(0)

df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   January       Acre          0   1/1/1998
# 1     1999   January       Acre          0   1/1/1999
# 2     2000   January       Acre          0   1/1/2000
# 3     2001   January       Acre          0   1/1/2001
# 4     2002   January       Acre          0   1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  December  Tocantins         128  1/1/2012
# 6450  2013  December  Tocantins          85  1/1/2013
# 6451  2014  December  Tocantins         223  1/1/2014
# 6452  2015  December  Tocantins         373  1/1/2015
# 6453  2016  December  Tocantins         119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
d = {'Name':['Guru','Ram','Sham','Sita','Ram','Sham'],
     'Std':[2,None,7,8,4,7],
     'div':['B','A','C',None,'A','C'],
     'rollno':[1,15,28,None,15,28]}
df = pd.DataFrame(d)
df
# Out:
#    Name  Std   div  rollno
# 0  Guru  2.0     B     1.0
# 1   Ram  NaN     A    15.0
# 2  Sham  7.0     C    28.0
# 3  Sita  8.0  None     NaN
# 4   Ram  4.0     A    15.0
# 5  Sham  7.0     C    28.0

# %%
d = {'div':'Division','Std':'Standard'}
df.rename(columns=d,inplace=True)
df
# Out:
#    Name  Standard Division  rollno
# 0  Guru       2.0        B     1.0
# 1   Ram       NaN        A    15.0
# 2  Sham       7.0        C    28.0
# 3  Sita       8.0     None     NaN
# 4   Ram       4.0        A    15.0
# 5  Sham       7.0        C    28.0

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#    Name  Standard Division  rollno
# 0  Guru       2.0        B     1.0
# 1   Ram       NaN        A    15.0
# 2  Sham       7.0        C    28.0
# 3  Sita       8.0     None     NaN
# 4   Ram       4.0        A    15.0

# %%
df['Standard'] = df['Standard'].fillna(0)
df['Percentage'] = [70,80,90,None,56]
df
# Out:
#    Name  Standard Division  rollno  Percentage
# 0  Guru       2.0        B     1.0        70.0
# 1   Ram       0.0        A    15.0        80.0
# 2  Sham       7.0        C    28.0        90.0
# 3  Sita       8.0     None     NaN         NaN
# 4   Ram       4.0        A    15.0        56.0

# %%
#handling null values, filling with 0 or avg
''''m = df['Percentage'].mean()
df['Percentage'] = df['Percentage'].fillna(m)
df'''
# Out:
#    Name  Standard Division  rollno  Percentage
# 0  Guru       2.0        B     1.0        70.0
# 1   Ram       0.0        A    15.0        80.0
# 2  Sham       7.0        C    28.0        90.0
# 3  Sita       8.0     None     NaN        74.0
# 4   Ram       4.0        A    15.0        56.0

# %%
df['Percentage']=df['Percentage'].fillna(method='ffill')
df
# Out:
# <ipython-input-16-e5d524905d34>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Percentage']=df['Percentage'].fillna(method='ffill')
#    Name  Standard Division  rollno  Percentage
# 0  Guru       2.0        B     1.0        70.0
# 1   Ram       0.0        A    15.0        80.0
# 2  Sham       7.0        C    28.0        90.0
# 3  Sita       8.0     None     NaN        74.0
# 4   Ram       4.0        A    15.0        56.0

# %%
df['Percentage']=[70,80,None,None,56]
df
# Out:
#    Name  Standard Division  rollno  Percentage  percentage
# 0  Guru       2.0        B     1.0        70.0        70.0
# 1   Ram       0.0        A    15.0        80.0        80.0
# 2  Sham       7.0        C    28.0         NaN         NaN
# 3  Sita       8.0     None     NaN         NaN         NaN
# 4   Ram       4.0        A    15.0        56.0        56.0

# %%
df['Percentage']=df['Percentage'].fillna(method='ffill')
df
# Out:
# <ipython-input-24-e5d524905d34>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Percentage']=df['Percentage'].fillna(method='ffill')
#    Name  Standard Division  rollno  Percentage  percentage
# 0  Guru       2.0        B     1.0         NaN        70.0
# 1   Ram       0.0        A    15.0        80.0        80.0
# 2  Sham       7.0        C    28.0        56.0         NaN
# 3  Sita       8.0     None     NaN        80.0         NaN
# 4   Ram       4.0        A    15.0        80.0        56.0

# %%
df['Percentage']=[None,80,56,80,None]
df
# Out:
#    Name  Standard Division  rollno  Percentage  percentage
# 0  Guru       2.0        B     1.0         NaN        70.0
# 1   Ram       0.0        A    15.0        80.0        80.0
# 2  Sham       7.0        C    28.0        56.0         NaN
# 3  Sita       8.0     None     NaN        80.0         NaN
# 4   Ram       4.0        A    15.0         NaN        56.0

# %%
df['Percentage']=df['Percentage'].fillna(method='backfill')
df
# Out:
# <ipython-input-25-6f6fba08602b>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Percentage']=df['Percentage'].fillna(method='backfill')
#    Name  Standard Division  rollno  Percentage  percentage
# 0  Guru       2.0        B     1.0        80.0        70.0
# 1   Ram       0.0        A    15.0        80.0        80.0
# 2  Sham       7.0        C    28.0        56.0         NaN
# 3  Sita       8.0     None     NaN        80.0         NaN
# 4   Ram       4.0        A    15.0        80.0        56.0

# %%
df.drop('percentage',inplace=True,axis=1)
df
# Out:
#    Name  Standard Division  rollno  Percentage
# 0  Guru       2.0        B     1.0        80.0
# 1   Ram       0.0        A    15.0        80.0
# 2  Sham       7.0        C    28.0        56.0
# 3  Sita       8.0     None     NaN        80.0
# 4   Ram       4.0        A    15.0        80.0

# %%
df.drop('Division',inplace=True,axis=1)
df
# Out:
#    Name  Standard  rollno  Percentage
# 0  Guru       2.0     1.0        80.0
# 1   Ram       0.0    15.0        80.0
# 2  Sham       7.0    28.0        56.0
# 3  Sita       8.0     NaN        80.0
# 4   Ram       4.0    15.0        80.0

# %%
df.drop(['Standard','Percentage'],axis=1,inplace=True)
df
# Out:
#    Name  rollno
# 0  Guru     1.0
# 1   Ram    15.0
# 2  Sham    28.0
# 3  Sita     NaN
# 4   Ram    15.0

# %%
df.drop(df.index[1],inplace=True)
df
# Out:
#    Name  rollno
# 0  Guru     1.0
# 2  Sham    28.0
# 3  Sita     NaN
# 4   Ram    15.0

# %%
df.reset_index(inplace=True)
df
# Out:
#    index  Name  rollno
# 0      0  Guru     1.0
# 1      2  Sham    28.0
# 2      3  Sita     NaN
# 3      4   Ram    15.0

# %%
df.drop('index',axis=1,inplace=True)
df
# Out:
#    Name  rollno
# 0  Guru     1.0
# 1  Sham    28.0
# 2  Sita     NaN
# 3   Ram    15.0

# %%
df1
# Out:
#       year     month      state no_of_fires      date
# 0     1998   January       Acre          0   1/1/1998
# 1     1999   January       Acre          0   1/1/1999
# 2     2000   January       Acre          0   1/1/2000
# 3     2001   January       Acre          0   1/1/2001
# 4     2002   January       Acre          0   1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  December  Tocantins         128  1/1/2012
# 6450  2013  December  Tocantins          85  1/1/2013
# 6451  2014  December  Tocantins         223  1/1/2014
# 6452  2015  December  Tocantins         373  1/1/2015
# 6453  2016  December  Tocantins         119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df1['month']=df1['month'].str.replace('January','Jan')
df1.head(50)
# Out:
#     year     month state no_of_fires      date
# 0   1998       Jan  Acre          0   1/1/1998
# 1   1999       Jan  Acre          0   1/1/1999
# 2   2000       Jan  Acre          0   1/1/2000
# 3   2001       Jan  Acre          0   1/1/2001
# 4   2002       Jan  Acre          0   1/1/2002
# 5   2003       Jan  Acre         10   1/1/2003
# 6   2004       Jan  Acre          0   1/1/2004
# 7   2005       Jan  Acre         12   1/1/2005
# 8   2006       Jan  Acre          4   1/1/2006
# 9   2007       Jan  Acre          0   1/1/2007
# 10  2008       Jan  Acre          0   1/1/2008
# 11  2009       Jan  Acre          0   1/1/2009
# 12  2010       Jan  Acre          1   1/1/2010
# 13  2011       Jan  Acre          0   1/1/2011
# 14  2012       Jan  Acre          0   1/1/2012
# 15  2013       Jan  Acre          0   1/1/2013
# 16  2014       Jan  Acre          0   1/1/2014
# 17  2015       Jan  Acre          1   1/1/2015
# 18  2016       Jan  Acre         12   1/1/2016
# ...

# %%
df1.set_index('year')
# Out:
#          month      state no_of_fires      date
# year
# 1998       Jan       Acre          0   1/1/1998
# 1999       Jan       Acre          0   1/1/1999
# 2000       Jan       Acre          0   1/1/2000
# 2001       Jan       Acre          0   1/1/2001
# 2002       Jan       Acre          0   1/1/2002
# ...        ...        ...         ...       ...
# 2012  December  Tocantins         128  1/1/2012
# 2013  December  Tocantins          85  1/1/2013
# 2014  December  Tocantins         223  1/1/2014
# 2015  December  Tocantins         373  1/1/2015
# 2016  December  Tocantins         119  1/1/2016
#
# [6424 rows x 4 columns]

# %%
df1.info()
df1['no_of_fires']=df1['no_of_fires'].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6424 non-null   int64
#  1   month        6424 non-null   object
#  2   state        6424 non-null   object
#  3   no_of_fires  6424 non-null   float64
#  4   date         6424 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 559.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6424 non-null   int64
#  1   month        6424 non-null   object
#  2   state        6424 non-null   object
#  3   no_of_fires  6424 non-null   int64
#  4   date         6424 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 559.2+ KB
